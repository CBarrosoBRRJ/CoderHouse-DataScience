# %%
# https://www.w3schools.com/colors/colors_mixer.asp

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
gyr = ["#1FD9E8","#47A6C9","#6680B2","#85599C","#A33385","#CC0066"]
sns.palplot(sns.color_palette(gyr))

# %%
glue = sns.load_dataset("glue").pivot("Model", "Task", "Score")
sns.heatmap(glue, annot = True, cmap = gyr)
